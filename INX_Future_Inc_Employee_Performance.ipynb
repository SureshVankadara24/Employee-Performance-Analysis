# %% [markdown]
# # <font color='Black'>Employee Performance Analysis

# %% [markdown]
# Recent years, the employee performance indexes are not healthy and this is becoming a growing concerns among the top management. There has been increased escalations on service delivery and client satisfaction levels came down by 8 percentage points.
#
# <p> The aim of the project is to :
#     <li> Analyse the current employee data and find the core underlying causes of this performance issues </li>
#     <li> Department wise performances </li>
#     <li> Top 3 Important Factors effecting employee performance </li>
#     <li> A trained model which can predict the employee performance based on factors as inputs. This will be used to    hire employees. </li>
#     <li> Recommendations to improve the employee performance based on insights from analysis. </li>

# %% [markdown]
# # <font color='black'>Table of Contents

# %% [markdown]
#  ###  1.<font color=F5775C><t> Importing Data

# %% [markdown]
# ### 2.<font color=F5775C> Reading and Comtemplating Data

# %% [markdown]
# ### 3.<font color=F5775C> Visualization and Data Cleaning

# %% [markdown]
# ### 4.<font color=F5775C > Modeling

# %% [markdown]
# ### 5.<font color=F5775C>  Conclusion

# %% [markdown]
# ### 6.<font color=F5775C> Recomendation based on insights

# %% [markdown]
# </n>
# </n>
# <p>
#     <b> <font color='grey'> Loading Relevant Libraries</b>
# <p>
#     <li> Pandas: Reading & Manipulating Tabular Data </li>
#     <li> Numpy: Numerical Operations in Python </li>
# </p> </p>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.csv')

# %% [markdown]
# # Importing Data <a href='1. Importing Data'>

# %% [markdown]
# We import data and check for any missing values and count the number of features.

# %%
df.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel        ...          EmpRelationshipSatisfaction  \
# 0                  3        ...                                    4
# ...

# %% [markdown]
# # Reading and Contempating Data

# %%
df.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %%
df.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %% [markdown]
# Since there are no missing values we can proceed futher along the dataset

# %% [markdown]
# # Visualization and Data Cleaning

# %% [markdown]
# <p> <b> Importing Libraries for visualization </b>
#     <li> Matplotlib</li>
#     <li> Seaborn </li>

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df['MaritalStatus'].value_counts()
# Out:
# Married     548
# Single      384
# Divorced    268
# Name: MaritalStatus, dtype: int64

# %%
status_mapping={'Married':0,'Single':1,'Divorced':2}

# %%
data=[df]

# %%
for dataset in data:
    dataset['Relationship']=dataset['MaritalStatus'].map(status_mapping)

# %%
Relationship=df['Relationship']

# %%
sb.distplot(Relationship)

# %% [markdown]
# - According to the graph and research, the people who are married performs good in work. Because they are happy and every work they do is filled with happiness.
# - People who are single they tend to be average
# - Divorced people has less focus on their work because of the heart break. They are mostly trying to figure things out basically tends to deviate their minds from their work. They are unstable which will effect their work.

# %%
sex_mapping={'Male':0,'Female':1}
for dataset in data:
    dataset['Sex']=dataset['Gender'].map(sex_mapping)

# %%
PerformanceRating=df['Sex']

# %%
sb.distplot(PerformanceRating)

# %% [markdown]
# - From the data and graph we can see that Men have higher work performance rating compare to women.
# - According to the survey and data available in the internet, women are more sacrificial than men once they have a family of their own, which tends to cut their working hours with the big margin when it all sums up at the end of the year.
# - Researchs have also shown that women are less likely to work late shifts in the night (for security reasons) while men have shown less signs of insecurity.
# - The graph doesn't discriminate in sexes but it is just the life situations that leads us to take certain choices.
# - But since the number of male is 725 and female 475 the data shows a good footprint of female in the coorporate world

# %% [markdown]
# # Age Grouping
#
# - Grouping helps to reduce the numbers and put into set for easy and better understanding of data.

# %%
for dataset in data:
    dataset['Age'] = dataset['Age'].astype(int)
    dataset.loc[ dataset['Age'] <= 22, 'Age'] = 0 
    dataset.loc[(dataset['Age'] > 22) & (dataset['Age'] <= 26), 'Age'] = 1 
    
    dataset.loc[(dataset['Age'] > 26) & (dataset['Age'] <= 30), 'Age'] = 2 
    dataset.loc[(dataset['Age'] > 30) & (dataset['Age'] <= 35), 'Age'] = 3
    dataset.loc[(dataset['Age'] > 35) & (dataset['Age'] <= 40), 'Age'] = 4
    dataset.loc[(dataset['Age'] > 40) & (dataset['Age'] <= 45), 'Age'] = 5
    dataset.loc[(dataset['Age'] > 45) & (dataset['Age'] <= 55), 'Age'] = 6
    dataset.loc[ dataset['Age'] > 55, 'Age'] = 7

# %%
Age=df['Age']
sb.distplot(Age)

# %% [markdown]
# - Most of the graduates are above 22
# - New comers tends to work for only 4 years or less before changing the job
# - People who get good performance rating are usually between 30 to 40 years of age. This group of people are hard working
# - People clossing to retirement doesnot get good ratings because maybe they have achieved so much that they tend loosen up a bit and enjoy the easier and successful life.

# %%
df['EmpEducationLevel'].value_counts()
# Out:
# 3    449
# 4    322
# 2    239
# 1    148
# 5     42
# Name: EmpEducationLevel, dtype: int64

# %%
Edu_level=df['EmpEducationLevel']

# %%
sb.distplot(Edu_level)

# %% [markdown]
# - People with level 3 education has highest performance rating than any other group.

# %%
df.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000    3   Male           Marketing        Single            Sales
# 1  E1001006    6   Male           Marketing        Single            Sales
# 2  E1001007    4   Male       Life Sciences       Married            Sales
# 3  E1001009    5   Male     Human Resources      Divorced  Human Resources
# 4  E1001010    7   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel ...   TrainingTimesLastYear  EmpWorkLifeBalance  \
# 0                  3 ...                       2                   2
# ...

# %% [markdown]
# # Distance Grouping

# %%
for dataset in data:
    dataset['DistanceFromHome']=dataset['DistanceFromHome'].astype(int)
    dataset.loc[ dataset['DistanceFromHome'] <= 5, 'DistanceFromHome'] = 0
    dataset.loc[(dataset['DistanceFromHome'] > 5) & (dataset['DistanceFromHome'] <= 10), 'DistanceFromHome'] = 1
    dataset.loc[(dataset['DistanceFromHome'] > 10) & (dataset['DistanceFromHome'] <= 15), 'DistanceFromHome'] = 2
    dataset.loc[(dataset['DistanceFromHome'] > 15) & (dataset['DistanceFromHome'] <= 20), 'DistanceFromHome'] = 3
    dataset.loc[(dataset['DistanceFromHome'] > 20) & (dataset['DistanceFromHome'] <= 25), 'DistanceFromHome'] = 4
    
    dataset.loc[ dataset['DistanceFromHome'] > 25, 'DistanceFromHome'] = 5

# %%
DistanceFromHome=df['DistanceFromHome']

# %%
df.plot(kind='hist',stacked=True, x='PerformanceRating',y='DistanceFromHome')

# %% [markdown]
# - People who stay near to the office are having higher performance ratings
# - People who are near say in 5km radius spend less time on the road fighting traffic frustration and losing energy while coming for work. These people are relatively fresh and active than other people specially people living more than 20km away from the working area.

# %%
df['EducationBackground'].value_counts()
# Out:
# Life Sciences       492
# Medical             384
# Marketing           137
# Technical Degree    100
# Other                66
# Human Resources      21
# Name: EducationBackground, dtype: int64

# %%
Education_mapping={'Life Sciences':0,'Medical':1,'Marketing':2,'Technical Degree':3,'Human Resources':4,'Other':5}

# %%
for dataset in data:
    dataset['Edu_Qualification']=dataset['EducationBackground'].map(Education_mapping)

# %%
Edu_Qualification=df['Edu_Qualification']
sb.regplot(x=Edu_Qualification, y=PerformanceRating, data=df)
df.plot(kind='hist',stacked=True, x='PerformanceRating',y='Edu_Qualification')

# %% [markdown]
# - People with technical degree should be encouraged because it will enhance the performance of the company. Since employee with technical knowlegde can explore the vast area in today's digital driven world.
# - Company needs data-scientist, software engineers, business and market related people.

# %%
df.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %%
df['Attrition'].value_counts()
# Out:
# No     1022
# Yes     178
# Name: Attrition, dtype: int64

# %%
Attrition_mapping = {'Yes':1, 'No':0}
for dataset in data:
    dataset['Attrition']=dataset['Attrition'].map(Attrition_mapping)

# %%
df['ExperienceYearsAtThisCompany'].describe()
# Out:
# count    1200.000000
# mean        7.077500
# std         6.236899
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%        10.000000
# max        40.000000
# Name: ExperienceYearsAtThisCompany, dtype: float64

# %%
OT={'Yes':1,'No':0}
for dataset in data:
    dataset['OT']=dataset['OverTime'].map(OT)

# %%
OT=df['OT']
sb.distplot(OT)

# %% [markdown]
# # Department wise performance

# %%
df['EmpDepartment'].value_counts()
# Out:
# Sales                     373
# Development               361
# Research & Development    343
# Human Resources            54
# Finance                    49
# Data Science               20
# Name: EmpDepartment, dtype: int64

# %%
Dept={'Sales':0,'Development':1,'Research & Development':2,'Human Resources':3,'Finance':4,'Data Science':5}

# %%
for dataset in data:
    dataset['Department']=dataset['EmpDepartment'].map(Dept)

# %%
Dept=df['Department']
sb.distplot(Dept)

# %% [markdown]
# - Data-science is not quite good in this company maybe because the company does not hire much data-scientist and that is why it not able to flourish.
# - The company is poor in hiring people with technical degree and technical employees are important as mentioned earlier

# %%
df['NumCompaniesWorked'].value_counts()
# Out:
# 1    433
# 0    156
# 3    133
# 2    123
# 4    107
# 7     60
# 6     56
# 5     53
# 8     40
# 9     39
# Name: NumCompaniesWorked, dtype: int64

# %%
N_comp=df['NumCompaniesWorked']
sb.distplot(N_comp)

# %% [markdown]
# The people who change a lot of companies will obviously get less promotion or performance ratings because they are likely to be unstable in terms of leaving the company.

# %%
df.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000    3   Male           Marketing        Single            Sales
# 1  E1001006    6   Male           Marketing        Single            Sales
# 2  E1001007    4   Male       Life Sciences       Married            Sales
# 3  E1001009    5   Male     Human Resources      Divorced  Human Resources
# 4  E1001010    7   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                 1
# 1  Sales Executive           Travel_Rarely                 2
# 2  Sales Executive       Travel_Frequently                 0
# 3          Manager           Travel_Rarely                 1
# 4  Sales Executive           Travel_Rarely                 3
#
#    EmpEducationLevel     ...      ExperienceYearsInCurrentRole  \
# 0                  3     ...                                 7
# ...

# %%
df['BusinessTravelFrequency'].value_counts()
# Out:
# Travel_Rarely        846
# Travel_Frequently    222
# Non-Travel           132
# Name: BusinessTravelFrequency, dtype: int64

# %%
travel={'Travel_Rarely':0,'Travel_Frequently':1, 'Non-Travel':2}
for dataset in data:
    dataset['TravelFrequency']=dataset['BusinessTravelFrequency'].map(travel)

# %%
travel=df['TravelFrequency']
sb.distplot(travel)

# %%
df['EmpJobRole'].value_counts()
# Out:
# Sales Executive              270
# Developer                    236
# Manager R&D                   94
# Research Scientist            77
# Sales Representative          69
# Laboratory Technician         64
# Senior Developer              52
# Manager                       51
# Finance Manager               49
# Human Resources               45
# Technical Lead                38
# Manufacturing Director        33
# Healthcare Representative     33
# Data Scientist                20
# Research Director             19
# Business Analyst              16
# Senior Manager R&D            15
# Delivery Manager              12
# Technical Architect            7
# Name: EmpJobRole, dtype: int64

# %%
Role={'Sales Executive':0,
'Developer':1,
'Manager R&D':2,
'Research Scientist':3,
'Sales Representative':4,
'Laboratory Technician':5,
'Senior Developer':6,
'Manager':7,
'Finance Manager':8,
'Human Resources':9,
'Technical Lead':10,
'Healthcare Representative':11,
'Manufacturing Director':12,
'Data Scientist':13,
'Research Director':14,
'Business Analyst':15,
'Senior Manager R&D':16,
'Delivery Manager':17,
'Technical Architect':18 }

# %%
for dataset in data:
    dataset['Role']=dataset['EmpJobRole'].map(Role)

# %%
role=df['Role']
df.plot(kind='hist',stacked= False, x='PerformanceRating',y='Role')

# %%
df.head(2)
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus EmpDepartment  \
# 0  E1001000    3   Male           Marketing        Single         Sales
# 1  E1001006    6   Male           Marketing        Single         Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                 1
# 1  Sales Executive           Travel_Rarely                 2
#
#    EmpEducationLevel  ...   YearsWithCurrManager  Attrition  \
# 0                  3  ...                      8          0
# 1                  4  ...                      7          0
#
#    PerformanceRating  Relationship  Sex  Edu_Qualification OT  Department  \
# 0                  3             1    0                  2  0           0
# 1                  3             1    0                  2  0           0
#
#    TravelFrequency  Role
# 0                0     0
# 1                0     0
#
# [2 rows x 35 columns]

# %%
df_new=df.drop(['EmpNumber','Gender','OverTime','EducationBackground','EmpJobSatisfaction','MaritalStatus','EmpDepartment','EmpJobRole','BusinessTravelFrequency','TravelFrequency'],axis=1)

# %% [markdown]
# Given below are the features that I dropped.
# - 'EmpNumber':Since they are unique and does not define anything in this dataset.
#
# <p> The features mentioned below are transformed into <b> Numeric Data </b> so the non-numeric features can be removed
#     - 'Gender'
#     - 'OverTime'
#     - 'EducationBackground'
#     - 'EmpJobSatisfaction'
#     - 'MaritalStatus'
#     - 'EmpDepartment'
#     - 'EmpJobRole'
#     - 'BusinessTravelFrequency'

# %%
df_new.isnull().sum()
# Out:
# Age                             0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# NumCompaniesWorked              0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# PerformanceRating               0
# Relationship                    0
# Sex                             0
# Edu_Qualification               0
# OT                              0
# Department                      0
# Role                            0
# dtype: int64

# %%
data_required= ['EmpLastSalaryHikePercent',
'EmpRelationshipSatisfaction',
'TotalWorkExperienceInYears',
'TrainingTimesLastYear',
'EmpWorkLifeBalance',
'ExperienceYearsAtThisCompany',
'ExperienceYearsInCurrentRole',
'YearsSinceLastPromotion',
'YearsWithCurrManager',
'Relationship',
'Sex',
'Edu_Qualification','Attrition']

# %%
for comparison in data_required:
    sb.jointplot(x='PerformanceRating', y=comparison, data=df, alpha=0.5, color='g', size=8, space=0)

# %%
#sb.pairplot(df_new, hue='PerformanceRating')

# %% [markdown]
# # Modeling
#
# <p>
#     <p>
#         <li> K_Nearest Neighbours</li>
#         <li> Random Forrest Classifier </li>
#         <li> SVC </li>

# %%
from IPython.display import Image
Image(filename='Scikit_learn.png')

# %% [markdown]
# Since the data is a Labeled data, my main model will be Random-Forrest.

# %% [markdown]
# <b> Spilting data into train and test </b>

# %%
train=df_new.drop(['PerformanceRating'],axis=1)
target=df_new['PerformanceRating']

# %% [markdown]
# <b> Train Data </b> Uses every feature in the new data set apart from 'Performance Rating which is used in <b> Target data. </b>
#
# All the data are important especially Sex because the reasons earlier mentioned above via Graph
#
# But <b> TravelFrequency </b>doesnot make sense. Most likely because people who travel rarely get higher rating and plus it has nothing to do with working.
#
# <p> The Most Important Features were :
#     <li> Sex: beacause it classify male or female </li>
#     <li> Age : because it divides people into several groups </li>
#     <li> Experience : it shows how employees are well-versed in thier job-profile </li>
#     <li> Distance from work : because it is important that employees come fresh into the office for work </li>
#     <li> Relationship: it plays a major role because it defines happiness of the employees. </li>
#     <li> EmpJobInvolvement</li>
#     <li> ExperienceYearsAtThisCompany: it based on trust. Hence important. </li>
#     <li> YearsWithCurrManager : Years with current manager is important since the manager knows how well versed and dedicated an employee is towards his/her work. </li>
#     <li> EmpRelationshipSatisfaction : A good relation with co-workers is very important. Because it defines you as a person. </li>
#    </p>
#
# PS: Since the accuracy score was very low I added the rest of the features.

# %%
from sklearn.model_selection import train_test_split, cross_val_score, KFold

# %% [markdown]
# To reduce and avoid overfitting I am using <b>cross_val_score </b> and <b> KFold </b> to use all the split train/test data for evaluation

# %% [markdown]
# ## K_nearest Neighbours
#
# The reason I am using nearest neighbours because it determines how close our sample is to the training set.

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
kfold=KFold(n_splits=20, shuffle=True, random_state=23)

# %%
clf=KNeighborsClassifier(n_neighbors=5)

# %%
score = cross_val_score(clf, train, target, cv=kfold, n_jobs=1)

# %%
score
# Out:
# array([ 0.83333333,  0.68333333,  0.66666667,  0.73333333,  0.71666667,
#         0.73333333,  0.65      ,  0.68333333,  0.76666667,  0.65      ,
#         0.75      ,  0.73333333,  0.71666667,  0.73333333,  0.6       ,
#         0.75      ,  0.65      ,  0.73333333,  0.75      ,  0.66666667])

# %%
round(np.mean(score)*100,2)
# Out:
# 71.0

# %%
clf.fit(train,target)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
clf.score(train,target)
# Out:
# 0.79833333333333334

# %% [markdown]
# ## Random_forrest C
#
# <p>
#     I Used random forrest because it is quite versatile and it is an enchanced version of decision tree. In Decision Tree a principle node is taken and decisions are made based on yes or no. In Random Forrest the we can have multiple decision trees which avoids overfitting.
#
#    Random forests creates decision trees on randomly selected data samples, gets prediction from each tree and selects the best solution by means of <b> voting </b>. It also provides a pretty good indicator of the feature importance.
#
#    It does not suffer from the overfitting problem. The main reason is that it takes the average of all the predictions, which cancels out the biases.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf4=RandomForestClassifier(n_estimators=26, criterion='entropy', max_depth=None, min_samples_split=12, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='sqrt', max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=23, verbose=7, warm_start=False, class_weight=None)

# %% [markdown]
# The reason I used 'Entropy' apart from 'gini' is because there are to many classification that makes up the data. So in order to find good exploratory analysis I used 'entropy.
# Besides it gives me higher accuracy.

# %%
score4=cross_val_score(clf4, train, target, cv=kfold, n_jobs=2)
# Out:
# building tree 1 of 26
# building tree 1 of 26
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# building tree 2 of 26
# building tree 2 of 26
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# building tree 3 of 26
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# building tree 3 of 26
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# building tree 4 of 26
# building tree 4 of 26
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# building tree 5 of 26
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# building tree 5 of 26
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s remaining:    0.0s
# ...

# %%
score4
# Out:
# array([ 0.93333333,  0.98333333,  0.88333333,  0.96666667,  0.9       ,
#         0.86666667,  0.95      ,  0.88333333,  0.96666667,  0.91666667,
#         0.93333333,  0.86666667,  0.91666667,  0.93333333,  0.93333333,
#         0.88333333,  0.86666667,  0.95      ,  0.9       ,  0.91666667])

# %%
round(np.mean(score4)*100,2)
# Out:
# 91.75

# %% [markdown]
# ## SVC

# %%
from sklearn.svm import SVC

# %%
clf5=SVC(C=5.0, kernel='linear', degree=3, gamma='auto', coef0=0.0, shrinking=True, probability=False, tol=0.001, cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape='ovr', random_state=None)

# %%
score5=cross_val_score(clf5, train, target, cv=kfold, n_jobs=1)

# %%
score5
# Out:
# array([ 0.88333333,  0.83333333,  0.68333333,  0.86666667,  0.86666667,
#         0.8       ,  0.78333333,  0.71666667,  0.8       ,  0.81666667,
#         0.85      ,  0.8       ,  0.83333333,  0.81666667,  0.71666667,
#         0.85      ,  0.71666667,  0.8       ,  0.66666667,  0.78333333])

# %%
round(np.mean(score5)*100,2)
# Out:
# 79.420000000000002

# %%
df_new.isnull().sum()
# Out:
# Age                             0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# NumCompaniesWorked              0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# PerformanceRating               0
# Relationship                    0
# Sex                             0
# Edu_Qualification               0
# OT                              0
# Department                      0
# Role                            0
# dtype: int64

# %% [markdown]
# Since RandomForrest Classifier gave me highest accuracy without overfitting I can use it for futher prediction.

# %%
clf4.fit(train,target)
# Out:
# building tree 1 of 26
# building tree 2 of 26
# building tree 3 of 26
# building tree 4 of 26
# building tree 5 of 26
# building tree 6 of 26
# building tree 7 of 26
# building tree 8 of 26
# building tree 9 of 26
# building tree 10 of 26
# building tree 11 of 26
# building tree 12 of 26
# building tree 13 of 26
# building tree 14 of 26
# building tree 15 of 26
# building tree 16 of 26
# building tree 17 of 26
# building tree 18 of 26
# building tree 19 of 26
# building tree 20 of 26
# building tree 21 of 26
# building tree 22 of 26
# building tree 23 of 26
# building tree 24 of 26
# building tree 25 of 26
# building tree 26 of 26
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# ...

# %% [markdown]
# ## Model_check

# %%
clf4.score(train,target)
# Out:
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    0.0s finished
# 0.96166666666666667

# %%
clf4.predict([[0,1,1,1,3,52,3,3,3,10,2,3,3,6,5,3,4,4,5,3,3,5,4,4]])
# Out:
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    0.0s finished
# array([2])

# %% [markdown]
# # Conclusion
#
# <p>
#     From given dataset I excluded all the string value and converted into numeric values
#     - <p>Some of the core problems that I observed was:
#         <li> Educational Qualification : more technical graduates should be employeed. This increase the morale of the other technical employees and likewise other departments. </li>
#         <li> Distance from work is another issue. Employees are fresh and proactive if their mood is good. Spending time in traffic may spoil their mood and it can affect their work. </li>
#         <li> Promotion plays a major role in the performance ratings.</li>
#         <li> Employees those who are having experience of ten years have higher ratings and then rating falls </li>
#         <li> According to the graph managers determines the performance rating. This should be stopped. Performance rating should be based on performance and irrespective of <b> Human interference </b>.
#
# </p> </p>

# %% [markdown]
# # Top 3 factors affecting employee's performance
#
# - Distance from work
# - Salary Hike
# - Promotion

# %% [markdown]
# # Recomdations based on insights
#
# <p>
#     <li> Technical graduates should be hired more </li>
#     <li> Promotions increases the morale of the employee. So employee with good reports should be promoted. </li>
#     <li> Employees with increasing experience should be given good performance rating. </li>
#     <li> Performance rating should be based entirely on performance. </li>
#     <li> Company should encourage good employee relationship. </li>
#     <li> Company should provide transportation benefits for people residing more than 5km. </li>
#     <li> Overtime should be encouraged only if company requires. And rating should be based on performance.
